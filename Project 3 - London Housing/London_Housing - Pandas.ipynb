# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge
#
#
# **Objective:** Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***

# %% [markdown]
# <br>
# <b><font color='green'>Ben, I will add comments in green for your convinience</font></b><br>
# <b><font color='red'>I will add questions I had in red to discuss with you or remember for myself</font></b>

# %% [markdown]
# <br>
# <br>
#
# ### 1. Sourcing and Loading

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#note: https://github.com/matplotlib/ipympl (for matplolib interactive features)

# %% [markdown]
# #### 1.2.  Loading the data
# The data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

df = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# <br>
# <br>
#
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.

# %% [markdown]
# <br>
#
# **2.1. Exploring your data**

# %% [markdown]
# <b><font color='green'>I first check the general information to see the data types, the columns, and the null values </font></b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            303 non-null    datetime64[ns]
#  1   City of London        304 non-null    object
#  2   Barking & Dagenham    304 non-null    object
#  3   Barnet                304 non-null    object
#  4   Bexley                304 non-null    object
#  5   Brent                 304 non-null    object
#  6   Bromley               304 non-null    object
#  7   Camden                304 non-null    object
#  8   Croydon               304 non-null    object
#  9   Ealing                304 non-null    object
#  10  Enfield               304 non-null    object
#  11  Greenwich             304 non-null    object
#  12  Hackney               304 non-null    object
#  13  Hammersmith & Fulham  304 non-null    object
#  14  Haringey              304 non-null    object
#  15  Harrow                304 non-null    object
#  16  Havering              304 non-null    object
#  17  Hillingdon            304 non-null    object
#  18  Hounslow              304 non-null    object
#  19  Islington             304 non-null    object
#  20  Kensington & Chelsea  304 non-null    object
#  21  Kingston upon Thames  304 non-null    object
#  22  Lambeth               304 non-null    object
#  23  Lewisham              304 non-null    object
#  24  Merton                304 non-null    object
#  25  Newham                304 non-null    object
#  26  Redbridge             304 non-null    object
#  27  Richmond upon Thames  304 non-null    object
#  28  Southwark             304 non-null    object
#  29  Sutton                304 non-null    object
#  30  Tower Hamlets         304 non-null    object
#  31  Waltham Forest        304 non-null    object
#  32  Wandsworth            304 non-null    object
#  33  Westminster           304 non-null    object
#  34  Unnamed: 34           0 non-null      float64
#  35  Inner London          304 non-null    object
#  36  Outer London          304 non-null    object
#  37  Unnamed: 37           0 non-null      float64
#  38  NORTH EAST            304 non-null    object
#  39  NORTH WEST            304 non-null    object
#  40  YORKS & THE HUMBER    304 non-null    object
#  41  EAST MIDLANDS         304 non-null    object
#  42  WEST MIDLANDS         304 non-null    object
#  43  EAST OF ENGLAND       304 non-null    object
#  44  LONDON                304 non-null    object
#  45  SOUTH EAST            304 non-null    object
#  46  SOUTH WEST            304 non-null    object
#  47  Unnamed: 47           0 non-null      float64
#  48  England               304 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(45)
# memory usage: 116.5+ KB

# %% [markdown]
# <br>
# <b><font color='green'>I also check the shape of the dataset and the head to get an ideas of how it is structured</font></b>

# %%
df.shape
# Out:
# (304, 49)

# %%
df.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %% [markdown]
# <br>
# <h5><b>Conclusions from this first section</b></h5>
# <br>
# <b><font color='green'>
#     <ul>
#         <li>We can see that the datatypes are objects not floats as we would like</li>
#         <li>We can see that there are several null columns with indeces 34,37,47.</li>
#         <li>There are also columns that do not provide us with relevant information for our question at hand (everything from column index 34 onwards) since they provide information about England in general and we are interested in only London boroughs</li>
#         <li>The City of London is apparently not considered a borough, so we will need to get rid of it as well.</li>
#         <li>Finally, the row with the NaT number is in fact the Local Authority District code names for the United Kingdom, this does not provide us relevant information now</li></ul>
# </font>
# </b>
#
# <br>
#
# [Local Authority Districts](http://geoportal.statistics.gov.uk/datasets/local-authority-districts-december-2017-names-and-codes-in-the-united-kingdom/data?page=2)
# <br><br>

# %% [markdown]
# **2.2. Cleaning the data**

# %%
df.iloc[:,34:]
# Out:
#      Unnamed: 34 Inner London Outer London  Unnamed: 37 NORTH EAST NORTH WEST  \
# 0            NaN    E13000001    E13000002          NaN  E12000001  E12000002
# 1            NaN        78252      72958.8          NaN    42076.4    43958.5
# 2            NaN      75885.7      72937.9          NaN      42572    43925.4
# 3            NaN      76591.6      72714.5          NaN    42369.7    44434.9
# 4            NaN      76851.6      72591.9          NaN    42095.8    44267.8
# ..           ...          ...          ...          ...        ...        ...
# 299          NaN       573932       423311          NaN     129658     165808
# 300          NaN       575132       423156          NaN     129504     164893
# 301          NaN       580890       422977          NaN     128425     165024
# 302          NaN       587586       425243          NaN     127741     165917
# 303          NaN       597617       424295          NaN     126945     166202
#
#     YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0            E12000003     E12000004     E12000005       E12000006  E12000007
# 1              44803.4       45544.5       48527.5         56701.6    74435.8
# 2              44528.8       46051.6       49341.3         56593.6    72777.9
# 3              45200.5       45383.8       49442.2         56171.2    73896.8
# 4              45614.3       46124.2       49455.9         56567.9    74455.3
# ..                 ...           ...           ...             ...        ...
# 299             164499        194855        200896          288781     468983
# 300             165818        194553        198644          290814     478576
# 301             164838        196277        202289          290548     479166
# 302             165232        193858        200577          291261     479974
# 303             159208        194664        195917          291254     485794
#
#     SOUTH EAST SOUTH WEST  Unnamed: 47    England
# 0    E12000008  E12000009          NaN  E92000001
# 1      64018.9    54705.2          NaN    53202.8
# 2        63715    54356.1          NaN    53096.2
# 3      64113.6    53583.1          NaN    53201.3
# 4      64623.2      54786          NaN    53590.9
# ..         ...        ...          ...        ...
# 299     322512     256875          NaN     247951
# 300     321972     256577          NaN     248250
# 301     323967     258185          NaN     249160
# 302     321268     258129          NaN     248587
# 303     323353     263360          NaN     248271
#
# [304 rows x 15 columns]

# %%
df = df.drop(df.iloc[:,34:], axis=1) # Drops the last columns

# %%
df = df.drop('City of London', axis=1) # Drops the last 'City of London' column

# %%
df = df.drop([0]) # Drops the NaT row

# %%
df.head() # Clean from unwanted columns and rows
# Out:
#   Unnamed: 0 Barking & Dagenham   Barnet   Bexley    Brent  Bromley  Camden  \
# 1 1995-01-01            50460.2  93284.5  64958.1  71306.6  81671.5  120933
# 2 1995-02-01            51085.8  93190.2  64787.9  72022.3  81657.6  119509
# 3 1995-03-01              51269  92247.5  64367.5  72015.8  81449.3  120282
# 4 1995-04-01            53133.5  90762.9  64277.7  72965.6  81124.4  120098
# 5 1995-05-01            53042.2    90258  63997.1    73704  81542.6  119929
#
#    Croydon   Ealing  Enfield  ...   Merton   Newham Redbridge  \
# 1  69158.2  79885.9  72514.7  ...  82070.6  53539.3   72189.6
# 2  68951.1  80897.1  73155.2  ...  79982.7  53153.9   72141.6
# 3  68712.4  81379.9  72190.4  ...  80661.7  53458.3   72501.4
# 4    68610  82188.9  71442.9  ...  79990.5  54479.8   72228.6
# 5  68844.9  82077.1  70630.8  ...    80874    55804   72366.6
#
#   Richmond upon Thames Southwark   Sutton Tower Hamlets Waltham Forest  \
# 1               109326   67885.2    71537       59865.2        61319.4
# 2               111103   64799.1  70893.2       62318.5        60252.1
# 3               107325   65763.3  70306.8       63938.7        60871.1
# 4               106875   63073.6  69411.9       66233.2        60971.4
# 5               107708   64420.5  69759.2       66432.9        61494.2
#
#   Wandsworth Westminster
# 1      88559      133025
# 2      88641      131468
# 3    87124.8      132260
# 4      87026      133370
# 5    86518.1      133911
#
# [5 rows x 33 columns]

# %% [markdown]
# <b><font color='red'>At this point a question came to mind. The introductory video said to transpose the table and make districts as columns. I do not understand where to locate datetime objects, categorical data, and other types of data. For example, what is the best index and the best column attributes? What is the best way to structure your data? How do I decide this?</font></b>

# %%
df.set_index(df.iloc[:,0], drop=True, inplace=True) # This sets the datetime column as index

# %%
df = df.drop(['Unnamed: 0'], axis=1) # For some reason the "drop" argument from before did not work so I need to drop it here

# %%
df.info() # This shows that we have the clean dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 303 entries, 1995-01-01 to 2020-03-01
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Barking & Dagenham    303 non-null    object
#  1   Barnet                303 non-null    object
#  2   Bexley                303 non-null    object
#  3   Brent                 303 non-null    object
#  4   Bromley               303 non-null    object
#  5   Camden                303 non-null    object
#  6   Croydon               303 non-null    object
#  7   Ealing                303 non-null    object
#  8   Enfield               303 non-null    object
#  9   Greenwich             303 non-null    object
#  10  Hackney               303 non-null    object
#  11  Hammersmith & Fulham  303 non-null    object
#  12  Haringey              303 non-null    object
#  13  Harrow                303 non-null    object
#  14  Havering              303 non-null    object
#  15  Hillingdon            303 non-null    object
#  16  Hounslow              303 non-null    object
#  17  Islington             303 non-null    object
#  18  Kensington & Chelsea  303 non-null    object
#  19  Kingston upon Thames  303 non-null    object
#  20  Lambeth               303 non-null    object
#  21  Lewisham              303 non-null    object
#  22  Merton                303 non-null    object
#  23  Newham                303 non-null    object
#  24  Redbridge             303 non-null    object
#  25  Richmond upon Thames  303 non-null    object
#  26  Southwark             303 non-null    object
#  27  Sutton                303 non-null    object
#  28  Tower Hamlets         303 non-null    object
#  29  Waltham Forest        303 non-null    object
#  30  Wandsworth            303 non-null    object
#  31  Westminster           303 non-null    object
# dtypes: object(32)
# memory usage: 78.1+ KB

# %%
df.index.name = 'Date' # For clarity sake I add the name of the index

# %%
#df_copy = df.copy()

# %% [markdown]
# <br>
#
# **2.3.Transforming the data**

# %%
df = df.apply(pd.to_numeric, errors='coerce') # We transform the object to a numeric data type

# %%
df.describe() # We check that it worked correctly by seeing the typical statistical values
# Out:
#        Barking & Dagenham         Barnet         Bexley          Brent  \
# count          303.000000     303.000000     303.000000     303.000000
# mean        160866.762697  306455.437541  190501.366135  271605.422138
# std          77158.176037  142117.801134   85925.728065  134692.643998
# min          50460.226600   90107.234710   63722.700550   71306.566980
# 25%          84590.936865  178724.560050  112441.242850  153318.460150
# 50%         163821.289300  305076.719500  194016.752400  264329.420100
# 75%         193325.098350  391382.992200  221080.929400  360443.588750
# max         327135.655200  549401.174400  347531.061710  519753.712470
#
#              Bromley         Camden        Croydon         Ealing  \
# count     303.000000     303.000000     303.000000     303.000000
# mean   255289.152870  470173.515540  210391.517241  275760.889754
# std    113506.304485  242795.595397   94183.966427  128926.947924
# min     81124.412270  115418.839600   68006.007350   79272.346180
# 25%    157741.232350  270697.425500  128247.871550  166667.957000
# 50%    257048.337000  446897.307100  212185.283300  270344.859100
# 75%    311738.867200  700612.593300  247840.897850  351108.404000
# max    449292.941540  890288.405600  378859.262200  489687.367900
#
#              Enfield      Greenwich  ...         Merton         Newham  \
# count     303.000000     303.000000  ...     303.000000     303.000000
# mean   224707.872657  214419.298108  ...  282721.763019  196871.963552
# std    102506.301990  104966.670244  ...  139790.305493   98450.021708
# min     70630.779550   60993.268630  ...   79569.228950   53153.883060
# 25%    131282.360500  123455.450250  ...  162375.877100  103953.539300
# 50%    226747.777100  214413.960900  ...  273054.193700  199911.813300
# 75%    272429.208750  267319.019150  ...  361864.373800  235146.449300
# max    404393.322000  415692.679400  ...  534090.591000  387326.229300
#
#            Redbridge  Richmond upon Thames      Southwark         Sutton  \
# count     303.000000            303.000000     303.000000     303.000000
# mean   236305.694067         384320.779745  276460.315629  218295.759738
# std    107893.180965         178847.797221  146617.186893   96510.912883
# min     72141.626100         106875.000000   60885.984830   69290.690040
# 25%    135577.844500         240253.547950  161503.185700  133743.976900
# 50%    242080.549700         364930.955500  263263.381000  219908.148800
# 75%    286381.341850         511363.753350  382081.645950  263599.616100
# max    430707.821280         682854.340600  535685.068800  387410.107910
#
#        Tower Hamlets  Waltham Forest     Wandsworth   Westminster
# count     303.000000      303.000000     303.000000  3.030000e+02
# mean   259316.496632   221800.935100  344088.988310  5.471234e+05
# std    125164.029333   120608.900182  172730.102831  3.055673e+05
# min     59865.189950    60252.122460   86518.059450  1.314683e+05
# 25%    159048.022050   112088.794200  202034.085350  2.855143e+05
# 50%    259013.923300   213044.152600  345344.349900  5.071399e+05
# 75%    345708.886100   271126.188200  484408.296150  8.550067e+05
# max    473409.700700   447630.020540  633826.050000  1.117408e+06
#
# [8 rows x 32 columns]

# %%
df.info() # We can now see that the data types are float like we wanted
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 303 entries, 1995-01-01 to 2020-03-01
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Barking & Dagenham    303 non-null    float64
#  1   Barnet                303 non-null    float64
#  2   Bexley                303 non-null    float64
#  3   Brent                 303 non-null    float64
#  4   Bromley               303 non-null    float64
#  5   Camden                303 non-null    float64
#  6   Croydon               303 non-null    float64
#  7   Ealing                303 non-null    float64
#  8   Enfield               303 non-null    float64
#  9   Greenwich             303 non-null    float64
#  10  Hackney               303 non-null    float64
#  11  Hammersmith & Fulham  303 non-null    float64
#  12  Haringey              303 non-null    float64
#  13  Harrow                303 non-null    float64
#  14  Havering              303 non-null    float64
#  15  Hillingdon            303 non-null    float64
#  16  Hounslow              303 non-null    float64
#  17  Islington             303 non-null    float64
#  18  Kensington & Chelsea  303 non-null    float64
#  19  Kingston upon Thames  303 non-null    float64
#  20  Lambeth               303 non-null    float64
#  21  Lewisham              303 non-null    float64
#  22  Merton                303 non-null    float64
#  23  Newham                303 non-null    float64
#  24  Redbridge             303 non-null    float64
#  25  Richmond upon Thames  303 non-null    float64
#  26  Southwark             303 non-null    float64
#  27  Sutton                303 non-null    float64
#  28  Tower Hamlets         303 non-null    float64
#  29  Waltham Forest        303 non-null    float64
#  30  Wandsworth            303 non-null    float64
#  31  Westminster           303 non-null    float64
# dtypes: float64(32)
# memory usage: 78.1 KB

# %%
df = df.reset_index() # I decide to reset the index now

# %%
df = pd.melt(df, id_vars=['Date'], value_vars=df.iloc[:,1:], var_name='Borough', value_name="Avg. Price")

# %%
df
# Out:
#            Date             Borough    Avg. Price
# 0    1995-01-01  Barking & Dagenham  5.046023e+04
# 1    1995-02-01  Barking & Dagenham  5.108578e+04
# 2    1995-03-01  Barking & Dagenham  5.126897e+04
# 3    1995-04-01  Barking & Dagenham  5.313351e+04
# 4    1995-05-01  Barking & Dagenham  5.304225e+04
# ...         ...                 ...           ...
# 9691 2019-11-01         Westminster  9.552646e+05
# 9692 2019-12-01         Westminster  9.609431e+05
# 9693 2020-01-01         Westminster  1.001284e+06
# 9694 2020-02-01         Westminster  1.042884e+06
# 9695 2020-03-01         Westminster  1.085013e+06
#
# [9696 rows x 3 columns]

# %%
pd.options.display.float_format='{:,.2f}'.format # I did not want to see so many digits so I tried to display only 2 decimals

# %%
df.head()
# Out:
#         Date             Borough  Avg. Price
# 0 1995-01-01  Barking & Dagenham   50,460.23
# 1 1995-02-01  Barking & Dagenham   51,085.78
# 2 1995-03-01  Barking & Dagenham   51,268.97
# 3 1995-04-01  Barking & Dagenham   53,133.51
# 4 1995-05-01  Barking & Dagenham   53,042.25

# %%
len(df.Borough.unique()) # We check that the number of boroughs is correct (there are 32)
# Out:
# 32

# %%
start_date = '1995-01-01'  # I will analyze the whole dataset from start to finish, the are the first and last observations
finish_date = '2020-03-01'

# %%
date_selection = (df['Date'] == start_date) | (df['Date'] == finish_date)

# %%
df_final = df.loc[date_selection]

# %%
df_final['Percent Change'] = df_final.loc[:,'Avg. Price'].pct_change()*100 # I did not understand the chained indexing that makes this warning appear. Anyway, this creates new column with the percent change
# Out:
# <ipython-input-28-f4657b2fa325>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Percent Change'] = df_final.loc[:,'Avg. Price'].pct_change()*100 # I did not understand the chained indexing that makes this warning appear. Anyway, this creates new column with the percent change

# %%
df_final_1 = pd.DataFrame(df_final.groupby('Borough')['Percent Change'].max()) # This only takes the first observation (this could yield problems if the price change had been negative...)

# %%
df_final['Abs Difference'] = df_final.loc[:,'Avg. Price'].diff() # I do the same for absolute values
# Out:
# <ipython-input-30-4390f17294d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Abs Difference'] = df_final.loc[:,'Avg. Price'].diff() # I do the same for absolute values

# %%
df_final_2 = pd.DataFrame(df_final.groupby('Borough')['Abs Difference'].max()) # Selects the biggest value

# %%
df_final = df_final_1.join(df_final_2) # Joins both tables with Percent Change and Absolute difference

# %%
df_final
# Out:
#                       Percent Change  Abs Difference
# Borough
# Barking & Dagenham            548.30      276,675.43
# Barnet                        470.91      439,284.43
# Bexley                        410.61      266,721.33
# Brent                         526.82      375,659.71
# Bromley                       426.54      348,361.34
# Camden                        628.58      760,163.07
# Croydon                       418.17      289,197.61
# Ealing                        468.34      374,141.46
# Enfield                       432.31      313,485.42
# Greenwich                     567.24      353,392.58
# Hackney                       941.96      577,386.61
# Hammersmith & Fulham          498.20      622,271.52
# Haringey                      641.07      489,054.95
# Harrow                        436.41      369,946.04
# Havering                      419.05      284,951.19
# Hillingdon                    466.10      344,142.35
# Hounslow                      485.67      350,810.67
# Islington                     583.41      539,753.06
# Kensington & Chelsea          664.17    1,213,407.40
# Kingston upon Thames          525.65      425,123.88
# Lambeth                       675.39      457,716.11
# Lewisham                      601.31      363,741.33
# Merton                        520.50      427,180.93
# Newham                        623.44      333,786.91
# Redbridge                     479.69      346,283.10
# Richmond upon Thames          479.44      524,154.39
# Southwark                     619.76      420,724.35
# Sutton                        427.64      305,921.50
# Tower Hamlets                 689.54      412,796.62
# Waltham Forest                612.91      375,833.86
# Wandsworth                    605.58      536,299.05
# Westminster                   715.64      951,987.42

# %%
df_final['max_rank_pc'] = df_final['Percent Change'].rank(method='max', ascending=False) # Generates a rank column for "Percent Change"

# %%
df_final['max_rank_ad'] = df_final['Abs Difference'].rank(method='max', ascending=False) # Generates a rank column for "Absolute Difference"

# %%
df_final = df_final[['Percent Change', 'max_rank_pc', 'Abs Difference', 'max_rank_ad']] # Reorders columns

# %%
df_final.sort_values('Percent Change', ascending=False) # Sorts by Percent Change
# Out:
#                       Percent Change  max_rank_pc  Abs Difference  max_rank_ad
# Borough
# Hackney                       941.96         1.00      577,386.61         5.00
# Westminster                   715.64         2.00      951,987.42         2.00
# Tower Hamlets                 689.54         3.00      412,796.62        15.00
# Lambeth                       675.39         4.00      457,716.11        10.00
# Kensington & Chelsea          664.17         5.00    1,213,407.40         1.00
# Haringey                      641.07         6.00      489,054.95         9.00
# Camden                        628.58         7.00      760,163.07         3.00
# Newham                        623.44         8.00      333,786.91        26.00
# Southwark                     619.76         9.00      420,724.35        14.00
# Waltham Forest                612.91        10.00      375,833.86        16.00
# Wandsworth                    605.58        11.00      536,299.05         7.00
# Lewisham                      601.31        12.00      363,741.33        20.00
# Islington                     583.41        13.00      539,753.06         6.00
# Greenwich                     567.24        14.00      353,392.58        21.00
# Barking & Dagenham            548.30        15.00      276,675.43        31.00
# Brent                         526.82        16.00      375,659.71        17.00
# Kingston upon Thames          525.65        17.00      425,123.88        13.00
# Merton                        520.50        18.00      427,180.93        12.00
# Hammersmith & Fulham          498.20        19.00      622,271.52         4.00
# Hounslow                      485.67        20.00      350,810.67        22.00
# Redbridge                     479.69        21.00      346,283.10        24.00
# Richmond upon Thames          479.44        22.00      524,154.39         8.00
# Barnet                        470.91        23.00      439,284.43        11.00
# Ealing                        468.34        24.00      374,141.46        18.00
# Hillingdon                    466.10        25.00      344,142.35        25.00
# Harrow                        436.41        26.00      369,946.04        19.00
# Enfield                       432.31        27.00      313,485.42        27.00
# Sutton                        427.64        28.00      305,921.50        28.00
# Bromley                       426.54        29.00      348,361.34        23.00
# Havering                      419.05        30.00      284,951.19        30.00
# Croydon                       418.17        31.00      289,197.61        29.00
# Bexley                        410.61        32.00      266,721.33        32.00

# %% [markdown]
# At this point we can answer the question of the challenge: **which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?**
#
# <font color='green'>We can analyze this taking into account both the relative and absolute value
#     <ul>
#         <li><b>Relative Value:</b> Hackney, Westminster, and Tower Hamlets were the ones that grew more in percent change</li>
#         <li><b>Absolute Value:</b> Kensington & Chelsea, Westminster, and Candem were the ones that grew more in absolute value</li>
#
# <font>

# %%
df_ratio = df[date_selection] # The document also asked to calculate the ratio, the next few lines do that

# %%
df_max = df_ratio.groupby('Borough').max()

# %%
df_min = df_ratio.groupby('Borough').min()

# %%
growth_ratio = [df_max['Avg. Price']/df_min['Avg. Price']]

# %%
growth_ratio
# Out:
# [Borough
#  Barking & Dagenham      6.48
#  Barnet                  5.71
#  Bexley                  5.11
#  Brent                   6.27
#  Bromley                 5.27
#  Camden                  7.29
#  Croydon                 5.18
#  Ealing                  5.68
#  Enfield                 5.32
#  Greenwich               6.67
#  Hackney                10.42
#  Hammersmith & Fulham    5.98
#  Haringey                7.41
#  Harrow                  5.36
#  Havering                5.19
#  Hillingdon              5.66
#  Hounslow                5.86
#  Islington               6.83
#  Kensington & Chelsea    7.64
#  Kingston upon Thames    6.26
#  Lambeth                 7.75
#  Lewisham                7.01
#  Merton                  6.21
#  Newham                  7.23
#  Redbridge               5.80
#  Richmond upon Thames    5.79
#  Southwark               7.20
#  Sutton                  5.28
#  Tower Hamlets           7.90
#  Waltham Forest          7.13
#  Wandsworth              7.06
#  Westminster             8.16
#  Name: Avg. Price, dtype: float64]

# %% [markdown]
# <br>
#
# **2.4. Visualizing the data**

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year  # I create the "year" column

# %%
df.head()
# Out:
#         Date             Borough  Avg. Price  Year
# 0 1995-01-01  Barking & Dagenham   50,460.23  1995
# 1 1995-02-01  Barking & Dagenham   51,085.78  1995
# 2 1995-03-01  Barking & Dagenham   51,268.97  1995
# 3 1995-04-01  Barking & Dagenham   53,133.51  1995
# 4 1995-05-01  Barking & Dagenham   53,042.25  1995

# %%
df_borough_year = df.groupby(['Borough','Year']).mean() # I group the values by borough and year just to avoid having so many values

# %%
df_borough_year.head()
# Out:
#                          Avg. Price
# Borough            Year
# Barking & Dagenham 1995   51,817.97
#                    1996   51,718.19
#                    1997   55,974.26
#                    1998   60,285.82
#                    1999   65,320.93

# %%
df_borough_year = df_borough_year.unstack() # I findit easier to analyse an unstacked table

# %%
df_borough_year.head()
# Out:
#                    Avg. Price                                             \
# Year                     1995      1996       1997       1998       1999
# Borough
# Barking & Dagenham  51,817.97 51,718.19  55,974.26  60,285.82  65,320.93
# Barnet              91,792.54 94,000.45 106,883.19 122,359.47 136,004.51
# Bexley              64,291.53 65,490.42  70,789.41  80,632.02  86,777.72
# Brent               73,029.84 75,235.92  86,749.07 100,692.59 112,157.47
# Bromley             81,967.32 83,547.48  94,224.69 108,286.52 120,874.18
#
#                                                                            \
# Year                     2000       2001       2002       2003       2004
# Borough
# Barking & Dagenham  77,549.51  88,664.06 112,221.91 142,498.93 158,175.98
# Barnet             167,952.63 185,563.35 220,746.06 251,212.93 271,854.11
# Bexley             103,186.67 116,527.13 136,797.96 164,482.04 179,141.17
# Brent              140,962.50 157,287.40 185,898.15 216,501.76 236,023.44
# Bromley            147,826.71 162,131.84 186,646.04 215,992.97 234,462.68
#
#                     ...                                              \
# Year                ...       2011       2012       2013       2014
# Borough             ...
# Barking & Dagenham  ... 163,465.14 165,863.91 173,733.62 201,172.23
# Barnet              ... 338,978.01 358,627.35 374,770.61 430,363.35
# Bexley              ... 200,672.26 202,546.43 213,470.26 244,459.44
# Brent               ... 298,964.55 314,112.76 339,655.61 394,687.48
# Bromley             ... 274,874.58 282,025.01 296,669.20 347,857.25
#
#                                                                            \
# Year                     2015       2016       2017       2018       2019
# Borough
# Barking & Dagenham 233,460.11 273,919.64 287,734.72 295,196.67 298,620.20
# Barnet             478,687.95 525,939.58 538,281.02 533,266.53 519,611.27
# Bexley             274,209.28 321,563.51 335,694.47 342,603.61 336,858.00
# Brent              440,951.67 489,469.42 487,703.75 492,845.37 474,513.08
# Bromley            385,681.45 428,008.12 441,218.59 443,409.99 436,459.81
#
#
# Year                     2020
# Borough
# Barking & Dagenham 312,014.15
# Barnet             524,550.04
# Bexley             333,651.68
# Brent              447,734.22
# Bromley            433,971.31
#
# [5 rows x 26 columns]

# %%
df_borough_year.columns = df_borough_year.columns.droplevel(0) # Drop column level 0

# %%
for i in range(0,31):

    label = df_borough_year.index[i]
    y_values = df_borough_year.iloc[i,:].values
    x_values = df_borough_year.iloc[i,:].index

    
    fig, ax = plt.subplots(figsize=(6,4))
    ax.plot(x_values, y_values)
    

    plt.title('Avg. Housing Price in the {} borough'.format(label))
    
    plt.show()

# %% [markdown]
# <b><font color='red'>I have hidden the graphs above. I wanted to make them as a matrix 8x4 but was not able, so currently 32 print out. Maybe you can give me some feedback on that point. Also the Kensington & Chelsea Borough has large values and I cannot change the ticks to be the same as the rest.</font></b>

# %%
print(df_borough_year.index)
print()
select_borough = ''
while select_borough not in df_borough_year.index:
    select_borough = input('Please select a borough from the list above')

i = df_borough_year.index.get_loc(select_borough)

label = df_borough_year.index[i]
y_values = df_borough_year.iloc[i,:].values
x_values = df_borough_year.iloc[i,:].index

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x_values, y_values)
ax.set_title('Avg. Housing Price in the {} borough'.format(label))

print()
plt.show()
# Out:
# Index(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden',
#        'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon',
#        'Hounslow', 'Islington', 'Kensington & Chelsea', 'Kingston upon Thames',
#        'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster'],
#       dtype='object', name='Borough')
# Please select a borough from the list above Sutton

# %% [markdown]
# <br>
#
# **Geopandas**

# %%
import geopandas as gpd
import adjustText

# %%
fp = 'Maps/ESRI/London_Borough_Excluding_MHW.shp'

# %%
map_df = gpd.read_file(fp)

# %%
map_df.head()
# Out:
#                    NAME   GSS_CODE  HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# 0  Kingston upon Thames  E09000021  3,726.12        0.00         F     None
# 1               Croydon  E09000008  8,649.44        0.00         F     None
# 2               Bromley  E09000006 15,013.49        0.00         F     None
# 3              Hounslow  E09000018  5,658.54       60.76         F     None
# 4                Ealing  E09000009  5,554.43        0.00         F     None
#
#   SUB_2006                                           geometry
# 0     None  POLYGON ((516401.600 160201.800, 516407.300 16...
# 1     None  POLYGON ((535009.200 159504.700, 535005.500 15...
# 2     None  POLYGON ((540373.600 157530.400, 540361.200 15...
# 3     None  POLYGON ((521975.800 178100.000, 521967.700 17...
# 4     None  POLYGON ((510253.500 182881.600, 510249.900 18...

# %%
map_df.plot()

# %%
map_df = map_df.set_index('NAME')

# %%
#map_df.drop(map_df.loc['City of London'], axis=0)

# %% [markdown]
# <b><font color='red'>At one point I tried this but it said: "unhashable type: 'Polygon'", do you know how to solve it?</font></b>

# %%
boroughs = ['Kingston upon Thames', 'Croydon', 'Bromley', 'Hounslow', 'Ealing',
       'Havering', 'Hillingdon', 'Harrow', 'Brent', 'Barnet', 'Lambeth',
       'Southwark', 'Lewisham', 'Greenwich', 'Bexley', 'Enfield',
       'Waltham Forest', 'Redbridge', 'Sutton', 'Richmond upon Thames',
       'Merton', 'Wandsworth', 'Hammersmith and Fulham',
       'Kensington and Chelsea', 'Westminster', 'Camden', 'Tower Hamlets',
       'Islington', 'Hackney', 'Haringey', 'Newham', 'Barking and Dagenham']

# %%
boroughs = sorted(boroughs)

# %%
df_final.index = boroughs

# %%
final_df = map_df.join(df_final)

# %%
final_df.head()
# Out:
#                        GSS_CODE  HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# NAME
# Kingston upon Thames  E09000021  3,726.12        0.00         F     None
# Croydon               E09000008  8,649.44        0.00         F     None
# Bromley               E09000006 15,013.49        0.00         F     None
# Hounslow              E09000018  5,658.54       60.76         F     None
# Ealing                E09000009  5,554.43        0.00         F     None
#
#                      SUB_2006  \
# NAME
# Kingston upon Thames     None
# Croydon                  None
# Bromley                  None
# Hounslow                 None
# Ealing                   None
#
#                                                                geometry  \
# NAME
# Kingston upon Thames  POLYGON ((516401.600 160201.800, 516407.300 16...
# Croydon               POLYGON ((535009.200 159504.700, 535005.500 15...
# Bromley               POLYGON ((540373.600 157530.400, 540361.200 15...
# Hounslow              POLYGON ((521975.800 178100.000, 521967.700 17...
# Ealing                POLYGON ((510253.500 182881.600, 510249.900 18...
#
#                       Percent Change  max_rank_pc  Abs Difference  max_rank_ad
# NAME
# Kingston upon Thames          525.65        17.00      425,123.88        13.00
# Croydon                       418.17        31.00      289,197.61        29.00
# Bromley                       426.54        29.00      348,361.34        23.00
# Hounslow                      485.67        20.00      350,810.67        22.00
# Ealing                        468.34        24.00      374,141.46        18.00

# %%
final_df['Center'] = final_df['geometry'].centroid

# %%
df_points = final_df.copy()

# %%
df_points.set_geometry('Center', inplace=True)

# %%
fig = plt.figure(dpi=150)

ax = final_df.plot(figsize = (18,14), color='whitesmoke', linewidth=0.8, ax= plt.gca(), edgecolor='0.8')
ax.axis('off')
texts = []

for x, y, label in zip(df_points.geometry.x, df_points.geometry.y, df_points.index):
    texts.append(plt.text(x, y,label,fontsize= 5))
    
adjustText.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), arrowprops=dict(arrowstyle='-',color='grey', lw=0.5))
# Out:
# 1

# %%
# variable
variable = 'Percent Change'

# range for the choropleth
vmin, vmax = 400, 950

# figures and exes for matplotlib
fig, ax = plt.subplots(1, figsize = (10,6))

# create map
final_df.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# remove the axis
ax.axis('off')

# add title
ax.set_title('Housing Price Index Percent Change 1995-2020', fontdict={'fontsize':'20','fontweight':'3'})

# annotation for data source
ax.annotate('Source: London Datastore',
           xy=(0.1,.08), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# colorband legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

# %%
# variable
variable = 'Percent Change'

# range for the choropleth
vmin, vmax = 400, 950

# figures and exes for matplotlib
fig, ax = plt.subplots(1, figsize = (15,12))

# create map
final_df.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# remove the axis
ax.axis('off')

# add title
ax.set_title('Housing Price Index Percent Change 1995-2020', fontdict={'fontsize':'20','fontweight':'3'})

# annotation for data source
ax.annotate('Source: London Datastore',
           xy=(0.1,.08), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# colorband legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

texts = []

for x, y, label in zip(df_points.geometry.x, df_points.geometry.y, df_points.index):
    texts.append(plt.text(x, y,label,fontsize= 8))
    
adjustText.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), arrowprops=dict(arrowstyle='-',color='grey', lw=0.5))
# Out:
# 1

# %% [markdown]
# <b><font color='red'>Is there a way to show some of the labels in white if the background is too dark?</font></b>

# %%
# variable
variable = 'Abs Difference'

# range for the choropleth
vmin, vmax = 0.27, 1.2

# figures and exes for matplotlib
fig, ax = plt.subplots(1, figsize = (10,6))

# create map
final_df.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# remove the axis
ax.axis('off')

# add title
ax.set_title('Housing Price Index Absolute Difference 1995-2020', fontdict={'fontsize':'20','fontweight':'3'})

# annotation for data source
ax.annotate('Source: London Datastore',
           xy=(0.1,.08), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# colorband legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

# %%
round((final_df['Abs Difference'].max())/1000000,2)
# Out:
# 1.21

# %%
round((final_df['Abs Difference'].min())/1000000,2)
# Out:
# 0.27

# %%
# variable
variable = 'Abs Difference'

# range for the choropleth
vmin, vmax = 0.27, 1.21

# figures and exes for matplotlib
fig, ax = plt.subplots(1, figsize = (15,12))

# create map
final_df.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# remove the axis
ax.axis('off')

# add title
ax.set_title('Housing Price Index Absolute Difference 1995-2020', fontdict={'fontsize':'20','fontweight':'3'})

# annotation for data source
ax.annotate('Source: London Datastore',
           xy=(0.1,.08), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# colorband legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

texts = []

for x, y, label in zip(df_points.geometry.x, df_points.geometry.y, df_points.index):
    texts.append(plt.text(x, y,label,fontsize= 8))
    
adjustText.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), arrowprops=dict(arrowstyle='-',color='grey', lw=0.5))
# Out:
# 1
